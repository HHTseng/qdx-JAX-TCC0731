# %%
import sys
sys.path.append(r'../')
from qdx.code_finder import CodeFinder
import os 
import jax
import time 
import json
import pickle
import numpy as np
import jax.numpy as jnp
from qdx.utils import Utils

import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
def exact_distance(n, k, gates):
    u = Utils(n, k, gates, softness=n-k)  # 完整檢查 stabilizer 組合
    for w in range(1, n + 1):
        num_kl_fail = int(u.check_KL(u.error_operators(w)))
        if num_kl_fail != 0:
            return w
    return n + 1
    
def kl_profile(n, k, gates, max_w):
    u = Utils(n, k, gates, softness=n-k)
    return {
        w: int(u.check_KL(u.error_operators(w)))
        for w in range(1, max_w + 1)
    }

# %% [markdown]
# # Example of [[7,1,3]] code discovery
#
# #### This corresponds to Fig.10 in the paper

# %%
# With a single config variable we define our training
# Variable names should be quite explanatory. Otherwise check Appendix C
config = {
    "ENV_TYPE": "STANDARD", # Possibilities: "STANDARD", "MAX", "DELTA", "NOISE-AWARE"
    "N": 7,
    "K": 1,
    "D": 3,
    "MAX_STEPS": 20,
    "WHICH_GATES": ["cx", "h"],
    "GRAPH": "All-to-All",
    "SOFTNESS": 1,
    "P_I": 0.9,
    "LAMBDA": 10,
    "SEED": 42,
    "LR": 1e-3,
    "NUM_ENVS": 16,
    "NUM_STEPS": 20,
    "TOTAL_TIMESTEPS": 2e6,
    "UPDATE_EPOCHS": 3,
    "NUM_MINIBATCHES": 4,
    "GAMMA": 0.99,
    "GAE_LAMBDA": 0.95,
    "CLIP_EPS": 0.2,
    "ENT_COEF": 0.02,
    "VF_COEF": 0.5,
    "MAX_GRAD_NORM": 0.25,
    "ACTIVATION": "relu",
    "HIDDEN_DIM": 32,
    "ANNEAL_LR": True,
    "NUM_AGENTS": 4,
    "COMPUTE_METRICS": True,
}


finder = CodeFinder(config)
# Training should take around 20sec
params, metrics = finder.train()
# Out:
# ==== Training started
# 2026-06-24 03:44:48.982059: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2026-06-24 03:44:48.982094: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2026-06-24 03:44:48.982109: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2026-06-24 03:44:48.982119: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2026-06-24 03:44:48.982129: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2026-06-24 03:44:48.982138: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2026-06-24 03:44:48.982146: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2026-06-24 03:44:48.982159: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2026-06-24 03:44:48.982168: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2026-06-24 03:44:48.982179: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2026-06-24 03:44:48.982188: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# ==== Training finished, time elapsed: 32.36350 s

# %% [markdown]
# ## Let's extract the returns and the circuit sizes to see the training trajectory

# %%
returns = metrics["returned_episode_returns"]
lengths = metrics["returned_episode_lengths"]

# %%
x = np.linspace(0, config["NUM_EPOCHS"], len(returns[0]))

# Each curve is a different agent
for i in range(config["NUM_AGENTS"]):
    plt.plot(x, returns[i])
plt.xlabel("Number of epochs")
plt.ylabel("Return")
plt.show() 

# Each curve is a different agent
for i in range(config["NUM_AGENTS"]):
    plt.plot(x, lengths[i])
plt.xlabel("Number of epochs")
plt.ylabel("Circuit size")
plt.show()

# %% [markdown]
# ## We can evaluate our agents to extract the circuits

# %%
data = finder.evaluate()

# %%
# We print the results from the first agent, for example
data[0]
# Out:
# {'n': 7,
#  'k': 1,
#  'd': 3,
#  'gates': ['.h(6)',
#   '.cx(6, 0)',
#   '.cx(0, 4)',
#   '.cx(6, 3)',
#   '.h(0)',
#   '.cx(0, 2)',
#   '.cx(6, 5)',
#   '.h(6)',
#   '.cx(6, 5)',
#   '.cx(6, 0)',
#   '.cx(0, 3)',
#   '.cx(0, 1)',
#   '.cx(0, 2)']}

# %% [markdown]
# ## Finally, let's visualize the discovered circuits

# %%
from IPython.display import SVG, display
import stim

gates = data[0]['gates']
actions = []

for g in gates:
    gate_name = g.split("(")[0].split(".")[1]
    qubit_ids = g.split("(")[1].split(")")[0]
    instruction = '.append("%s", [%s])' % (gate_name, qubit_ids)
        
    actions.append(instruction)
    

circ = stim.Circuit()
for action in actions:
    eval('circ%s' % action)
    
circ.diagram('timeline-svg')
# Out:
# <svg viewBox="0 0 800 544"  version="1.1" xmlns="http://www.w3.org/2000/svg">
# <g id="qubit_lines">
# <path id="qubit_line:0" d="M64,64 L768,64 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="64">q0</text>
# <path id="qubit_line:1" d="M64,128 L768,128 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="128">q1</text>
# <path id="qubit_line:2" d="M64,192 L768,192 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="192">q2</text>
# <path id="qubit_line:3" d="M64,256 L768,256 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="256">q3</text>
# <path id="qubit_line:4" d="M64,320 L768,320 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="320">q4</text>
# <path id="qubit_line:5" d="M64,384 L768,384 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="384">q5</text>
# <path id="qubit_line:6" d="M64,448 L768,448 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="448">q6</text>
# </g>
# <rect x="80" y="432" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="96" y="448">H</text>
# <path d="M160,64 L160,448 " stroke="black"/>
# <circle cx="160" cy="448" r="12" stroke="none" fill="black"/>
# <circle cx="160" cy="64" r="12" stroke="black" fill="white"/>
# <path d="M148,64 L172,64 M160,52 L160,76 " stroke="black"/>
# <path d="M224,64 L224,320 " stroke="black"/>
# <circle cx="224" cy="64" r="12" stroke="none" fill="black"/>
# <circle cx="224" cy="320" r="12" stroke="black" fill="white"/>
# <path d="M212,320 L236,320 M224,308 L224,332 " stroke="black"/>
# <path d="M288,256 L288,448 " stroke="black"/>
# <circle cx="288" cy="448" r="12" stroke="none" fill="black"/>
# <circle cx="288" cy="256" r="12" stroke="black" fill="white"/>
# <path d="M276,256 L300,256 M288,244 L288,268 " stroke="black"/>
# <rect x="272" y="48" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="288" y="64">H</text>
# <path d="M352,64 L352,192 " stroke="black"/>
# <circle cx="352" cy="64" r="12" stroke="none" fill="black"/>
# <circle cx="352" cy="192" r="12" stroke="black" fill="white"/>
# <path d="M340,192 L364,192 M352,180 L352,204 " stroke="black"/>
# <path d="M352,384 L352,448 " stroke="black"/>
# <circle cx="352" cy="448" r="12" stroke="none" fill="black"/>
# <circle cx="352" cy="384" r="12" stroke="black" fill="white"/>
# <path d="M340,384 L364,384 M352,372 L352,396 " stroke="black"/>
# <rect x="400" y="432" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="416" y="448">H</text>
# <path d="M480,384 L480,448 " stroke="black"/>
# <circle cx="480" cy="448" r="12" stroke="none" fill="black"/>
# <circle cx="480" cy="384" r="12" stroke="black" fill="white"/>
# <path d="M468,384 L492,384 M480,372 L480,396 " stroke="black"/>
# <path d="M544,64 L544,448 " stroke="black"/>
# <circle cx="544" cy="448" r="12" stroke="none" fill="black"/>
# <circle cx="544" cy="64" r="12" stroke="black" fill="white"/>
# <path d="M532,64 L556,64 M544,52 L544,76 " stroke="black"/>
# <path d="M608,64 L608,256 " stroke="black"/>
# <circle cx="608" cy="64" r="12" stroke="none" fill="black"/>
# <circle cx="608" cy="256" r="12" stroke="black" fill="white"/>
# <path d="M596,256 L620,256 M608,244 L608,268 " stroke="black"/>
# <path d="M672,64 L672,128 " stroke="black"/>
# <circle cx="672" cy="64" r="12" stroke="none" fill="black"/>
# <circle cx="672" cy="128" r="12" stroke="black" fill="white"/>
# <path d="M660,128 L684,128 M672,116 L672,140 " stroke="black"/>
# <path d="M736,64 L736,192 " stroke="black"/>
# <circle cx="736" cy="64" r="12" stroke="none" fill="black"/>
# <circle cx="736" cy="192" r="12" stroke="black" fill="white"/>
# <path d="M724,192 L748,192 M736,180 L736,204 " stroke="black"/>
# </svg>

# %%
profile = kl_profile(config["N"], config["K"], gates, config["D"])
print(profile)
# Out:
# {1: 0, 2: 0, 3: 27}

# %% [markdown]
# # Example of [[6,1]] code discovery with the noise-aware meta agent
#
# We choose d=4 since we know it will not succeed. We therefore force it to correct the most dangerous errors only

# %%
config = {
    "ENV_TYPE": "NOISE-AWARE", # Possibilities: "STANDARD", "MAX", "DELTA", "NOISE-AWARE"
    "N": 6,
    "K": 1,
    "D": 4,
    "MAX_STEPS": 30,
    "WHICH_GATES": ["cx", "h", "s"],
    "GRAPH": "All-to-All",
    "SOFTNESS": 1,
    "P_I": 0.9,
    "LAMBDA": 1,
    "SEED": 42,
    "LR": 5e-4,
    "NUM_ENVS": 64,
    "NUM_STEPS": 8,
    "TOTAL_TIMESTEPS": 4e6,
    "UPDATE_EPOCHS": 4,
    "NUM_MINIBATCHES": 8,
    "GAMMA": .99,
    "GAE_LAMBDA": 0.95,
    "CLIP_EPS": 0.1,
    "ENT_COEF": 0.01,
    "VF_COEF": 0.5,
    "MAX_GRAD_NORM": 0.05,
    "ACTIVATION": "relu",
    "HIDDEN_DIM": 200,
    "ANNEAL_LR": True,
    "NUM_AGENTS": 4,
    "COMPUTE_METRICS": True,
}


finder = CodeFinder(config)
# Training is now more costly. It should train in approx 60 sec.
params, metrics = finder.train()
# Out:
# ==== Training started
# 2026-06-24 03:45:31.265895: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2026-06-24 03:45:31.265961: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2026-06-24 03:45:31.265978: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2026-06-24 03:45:31.265990: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2026-06-24 03:45:31.266030: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2026-06-24 03:45:31.266053: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2026-06-24 03:45:31.266067: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2026-06-24 03:45:31.266080: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# ==== Training finished, time elapsed: 53.15446 s

# %% [markdown]
# ## Let's extract the returns and the circuit sizes to follow the training trajectory

# %%
returns = metrics["returned_episode_returns"]
lengths = metrics["returned_episode_lengths"]

# %%
x = np.linspace(0, config["NUM_EPOCHS"], len(returns[0]))

# Each curve is a different agent
for i in range(config["NUM_AGENTS"]):
    plt.plot(x, returns[i])
plt.xlabel("Number of epochs")
plt.ylabel("Return")
plt.show() 

# Each curve is a different agent
for i in range(config["NUM_AGENTS"]):
    plt.plot(x, lengths[i])
plt.xlabel("Number of epochs")
plt.ylabel("Circuit size")
plt.show()

# %% [markdown]
# The circuit size now does not decrease! This is due to the fact that the meta-agent cannot correct all the errors that we asked (by design) and instead corrects the most dangerous ones

# %% [markdown]
# ## We can evaluate our agents to extract the circuits

# %%
# Evaluation is now more costly because each agent is evaluated at 16 different values of cZ
# TODO: Accelerate evaluation with vmap
data = finder.evaluate()

# %%
# Technically, the effective distance d_eff should be an integer. 
# Here it should be read as the smallest undetected effective weight
data[0]
# Out:
# {'n': 6,
#  'k': 1,
#  'cZ': 0.5,
#  'd_eff': 1.5,
#  'gates': ['.cx(0, 4)',
#   '.h(0)',
#   '.cx(0, 4)',
#   '.cx(4, 5)',
#   '.h(4)',
#   '.cx(0, 2)',
#   '.cx(4, 2)',
#   '.h(0)',
#   '.cx(5, 1)',
#   '.cx(0, 1)',
#   '.cx(4, 1)',
#   '.h(4)',
#   '.h(0)',
#   '.cx(0, 3)',
#   '.s(3)',
#   '.h(0)',
#   '.s(1)',
#   '.s(2)',
#   '.h(1)',
#   '.s(1)',
#   '.s(1)',
#   '.s(1)',
#   '.s(1)',
#   '.s(1)',
#   '.s(1)',
#   '.s(1)',
#   '.s(1)',
#   '.s(1)',
#   '.s(1)',
#   '.s(1)']}

# %% [markdown]
# ## Finally, let's visualize the discovered circuits
#
# There might be a bunch of S gates applied at the very end. These can be ignored!

# %%
from IPython.display import SVG, display
import stim

gates = data[0]['gates']
actions = []

for g in gates:
    gate_name = g.split("(")[0].split(".")[1]
    qubit_ids = g.split("(")[1].split(")")[0]
    instruction = '.append("%s", [%s])' % (gate_name, qubit_ids)
        
    actions.append(instruction)
    

circ = stim.Circuit()
for action in actions:
    eval('circ%s' % action)
    
circ.diagram('timeline-svg')
# Out:
# <svg viewBox="0 0 1632 480"  version="1.1" xmlns="http://www.w3.org/2000/svg">
# <g id="qubit_lines">
# <path id="qubit_line:0" d="M64,64 L1600,64 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="64">q0</text>
# <path id="qubit_line:1" d="M64,128 L1600,128 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="128">q1</text>
# <path id="qubit_line:2" d="M64,192 L1600,192 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="192">q2</text>
# <path id="qubit_line:3" d="M64,256 L1600,256 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="256">q3</text>
# <path id="qubit_line:4" d="M64,320 L1600,320 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="320">q4</text>
# <path id="qubit_line:5" d="M64,384 L1600,384 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="384">q5</text>
# </g>
# <path d="M96,64 L96,320 " stroke="black"/>
# <circle cx="96" cy="64" r="12" stroke="none" fill="black"/>
# <circle cx="96" cy="320" r="12" stroke="black" fill="white"/>
# <path d="M84,320 L108,320 M96,308 L96,332 " stroke="black"/>
# <rect x="144" y="48" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="160" y="64">H</text>
# <path d="M224,64 L224,320 " stroke="black"/>
# <circle cx="224" cy="64" r="12" stroke="none" fill="black"/>
# <circle cx="224" cy="320" r="12" stroke="black" fill="white"/>
# <path d="M212,320 L236,320 M224,308 L224,332 " stroke="black"/>
# <path d="M288,320 L288,384 " stroke="black"/>
# <circle cx="288" cy="320" r="12" stroke="none" fill="black"/>
# <circle cx="288" cy="384" r="12" stroke="black" fill="white"/>
# <path d="M276,384 L300,384 M288,372 L288,396 " stroke="black"/>
# <rect x="336" y="304" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="320">H</text>
# <path d="M352,64 L352,192 " stroke="black"/>
# <circle cx="352" cy="64" r="12" stroke="none" fill="black"/>
# <circle cx="352" cy="192" r="12" stroke="black" fill="white"/>
# <path d="M340,192 L364,192 M352,180 L352,204 " stroke="black"/>
# <path d="M416,192 L416,320 " stroke="black"/>
# <circle cx="416" cy="320" r="12" stroke="none" fill="black"/>
# <circle cx="416" cy="192" r="12" stroke="black" fill="white"/>
# <path d="M404,192 L428,192 M416,180 L416,204 " stroke="black"/>
# <rect x="400" y="48" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="416" y="64">H</text>
# <path d="M480,128 L480,384 " stroke="black"/>
# <circle cx="480" cy="384" r="12" stroke="none" fill="black"/>
# <circle cx="480" cy="128" r="12" stroke="black" fill="white"/>
# <path d="M468,128 L492,128 M480,116 L480,140 " stroke="black"/>
# <path d="M544,64 L544,128 " stroke="black"/>
# <circle cx="544" cy="64" r="12" stroke="none" fill="black"/>
# <circle cx="544" cy="128" r="12" stroke="black" fill="white"/>
# <path d="M532,128 L556,128 M544,116 L544,140 " stroke="black"/>
# <path d="M608,128 L608,320 " stroke="black"/>
# <circle cx="608" cy="320" r="12" stroke="none" fill="black"/>
# <circle cx="608" cy="128" r="12" stroke="black" fill="white"/>
# <path d="M596,128 L620,128 M608,116 L608,140 " stroke="black"/>
# <rect x="656" y="304" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="672" y="320">H</text>
# <rect x="656" y="48" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="672" y="64">H</text>
# <path d="M736,64 L736,256 " stroke="black"/>
# <circle cx="736" cy="64" r="12" stroke="none" fill="black"/>
# <circle cx="736" cy="256" r="12" stroke="black" fill="white"/>
# <path d="M724,256 L748,256 M736,244 L736,268 " stroke="black"/>
# <rect x="784" y="240" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="800" y="256">S</text>
# <rect x="784" y="48" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="800" y="64">H</text>
# <rect x="784" y="112" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="800" y="128">S</text>
# <rect x="784" y="176" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="800" y="192">S</text>
# <rect x="848" y="112" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="864" y="128">H</text>
# <rect x="912" y="112" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="928" y="128">S</text>
# <rect x="976" y="112" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="992" y="128">S</text>
# <rect x="1040" y="112" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="1056" y="128">S</text>
# <rect x="1104" y="112" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="1120" y="128">S</text>
# <rect x="1168" y="112" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="1184" y="128">S</text>
# <rect x="1232" y="112" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="1248" y="128">S</text>
# <rect x="1296" y="112" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="1312" y="128">S</text>
# <rect x="1360" y="112" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="1376" y="128">S</text>
# <rect x="1424" y="112" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="1440" y="128">S</text>
# <rect x="1488" y="112" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="1504" y="128">S</text>
# <rect x="1552" y="112" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="1568" y="128">S</text>
# </svg>

# %%
profile = kl_profile(config["N"], config["K"], gates, config["D"])
print(profile)
# Out:
# {1: 0, 2: 0, 3: 24, 4: 24}

# %%
# With a single config variable we define our training
# Variable names should be quite explanatory. Otherwise check Appendix C
config = {
    "ENV_TYPE": "STANDARD", # Possibilities: "STANDARD", "MAX", "DELTA", "NOISE-AWARE"
    "N": 10,
    "K": 3,
    "D": 3,
    "MAX_STEPS": 40,
    "WHICH_GATES": ["cx", "h"],
    "GRAPH": "All-to-All",
    "SOFTNESS": 1,
    "P_I": 0.9,
    "LAMBDA": 10,
    "SEED": 42,
    "LR": 1e-3,
    "NUM_ENVS": 64,
    "NUM_STEPS": 100,
    "TOTAL_TIMESTEPS": 2e6,
    "UPDATE_EPOCHS": 10,
    "NUM_MINIBATCHES": 4,
    "GAMMA": 0.99,
    "GAE_LAMBDA": 0.95,
    "CLIP_EPS": 0.2,
    "ENT_COEF": 0.02,
    "VF_COEF": 0.5,
    "MAX_GRAD_NORM": 0.25,
    "ACTIVATION": "relu",
    "HIDDEN_DIM": 64,
    "ANNEAL_LR": True,
    "NUM_AGENTS": 4,
    "COMPUTE_METRICS": True,
}


finder = CodeFinder(config)
# Training should take around 20sec
params, metrics = finder.train()
# Out:
# ==== Training started
# ==== Training finished, time elapsed: 25.57802 s

# %%
returns = metrics["returned_episode_returns"]
lengths = metrics["returned_episode_lengths"]

# %%
x = np.linspace(0, config["NUM_EPOCHS"], len(returns[0]))

# Each curve is a different agent
for i in range(config["NUM_AGENTS"]):
    plt.plot(x, returns[i])
plt.xlabel("Number of epochs")
plt.ylabel("Return")
plt.show() 

# Each curve is a different agent
for i in range(config["NUM_AGENTS"]):
    plt.plot(x, lengths[i])
plt.xlabel("Number of epochs")
plt.ylabel("Circuit size")
plt.show()

# %%
data = finder.evaluate()
# We print the results from the first agent, for example
data[0]
# Out:
# {'n': 10,
#  'k': 3,
#  'd': 3,
#  'gates': ['.h(8)',
#   '.cx(8, 0)',
#   '.cx(8, 2)',
#   '.cx(2, 5)',
#   '.cx(1, 5)',
#   '.cx(8, 1)',
#   '.cx(0, 6)',
#   '.cx(2, 3)',
#   '.h(3)',
#   '.cx(3, 0)',
#   '.cx(3, 4)',
#   '.cx(1, 4)',
#   '.h(5)',
#   '.cx(5, 6)',
#   '.h(1)',
#   '.cx(1, 9)',
#   '.cx(8, 7)',
#   '.cx(1, 2)',
#   '.cx(0, 1)',
#   '.cx(5, 0)',
#   '.cx(2, 0)']}

# %%
from IPython.display import SVG, display
import stim

gates = data[0]['gates']
actions = []

for g in gates:
    gate_name = g.split("(")[0].split(".")[1]
    qubit_ids = g.split("(")[1].split(")")[0]
    instruction = '.append("%s", [%s])' % (gate_name, qubit_ids)
        
    actions.append(instruction)
    

circ = stim.Circuit()
for action in actions:
    eval('circ%s' % action)
    
circ.diagram('timeline-svg')
# Out:
# <svg viewBox="0 0 1248 736"  version="1.1" xmlns="http://www.w3.org/2000/svg">
# <g id="qubit_lines">
# <path id="qubit_line:0" d="M64,64 L1216,64 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="64">q0</text>
# <path id="qubit_line:1" d="M64,128 L1216,128 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="128">q1</text>
# <path id="qubit_line:2" d="M64,192 L1216,192 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="192">q2</text>
# <path id="qubit_line:3" d="M64,256 L1216,256 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="256">q3</text>
# <path id="qubit_line:4" d="M64,320 L1216,320 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="320">q4</text>
# <path id="qubit_line:5" d="M64,384 L1216,384 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="384">q5</text>
# <path id="qubit_line:6" d="M64,448 L1216,448 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="448">q6</text>
# <path id="qubit_line:7" d="M64,512 L1216,512 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="512">q7</text>
# <path id="qubit_line:8" d="M64,576 L1216,576 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="576">q8</text>
# <path id="qubit_line:9" d="M64,640 L1216,640 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="640">q9</text>
# </g>
# <rect x="80" y="560" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="96" y="576">H</text>
# <path d="M160,64 L160,576 " stroke="black"/>
# <circle cx="160" cy="576" r="12" stroke="none" fill="black"/>
# <circle cx="160" cy="64" r="12" stroke="black" fill="white"/>
# <path d="M148,64 L172,64 M160,52 L160,76 " stroke="black"/>
# <path d="M224,192 L224,576 " stroke="black"/>
# <circle cx="224" cy="576" r="12" stroke="none" fill="black"/>
# <circle cx="224" cy="192" r="12" stroke="black" fill="white"/>
# <path d="M212,192 L236,192 M224,180 L224,204 " stroke="black"/>
# <path d="M288,192 L288,384 " stroke="black"/>
# <circle cx="288" cy="192" r="12" stroke="none" fill="black"/>
# <circle cx="288" cy="384" r="12" stroke="black" fill="white"/>
# <path d="M276,384 L300,384 M288,372 L288,396 " stroke="black"/>
# <path d="M352,128 L352,384 " stroke="black"/>
# <circle cx="352" cy="128" r="12" stroke="none" fill="black"/>
# <circle cx="352" cy="384" r="12" stroke="black" fill="white"/>
# <path d="M340,384 L364,384 M352,372 L352,396 " stroke="black"/>
# <path d="M416,128 L416,576 " stroke="black"/>
# <circle cx="416" cy="576" r="12" stroke="none" fill="black"/>
# <circle cx="416" cy="128" r="12" stroke="black" fill="white"/>
# <path d="M404,128 L428,128 M416,116 L416,140 " stroke="black"/>
# <path d="M480,64 L480,448 " stroke="black"/>
# <circle cx="480" cy="64" r="12" stroke="none" fill="black"/>
# <circle cx="480" cy="448" r="12" stroke="black" fill="white"/>
# <path d="M468,448 L492,448 M480,436 L480,460 " stroke="black"/>
# <path d="M544,192 L544,256 " stroke="black"/>
# <circle cx="544" cy="192" r="12" stroke="none" fill="black"/>
# <circle cx="544" cy="256" r="12" stroke="black" fill="white"/>
# <path d="M532,256 L556,256 M544,244 L544,268 " stroke="black"/>
# <rect x="592" y="240" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="608" y="256">H</text>
# <path d="M672,64 L672,256 " stroke="black"/>
# <circle cx="672" cy="256" r="12" stroke="none" fill="black"/>
# <circle cx="672" cy="64" r="12" stroke="black" fill="white"/>
# <path d="M660,64 L684,64 M672,52 L672,76 " stroke="black"/>
# <path d="M736,256 L736,320 " stroke="black"/>
# <circle cx="736" cy="256" r="12" stroke="none" fill="black"/>
# <circle cx="736" cy="320" r="12" stroke="black" fill="white"/>
# <path d="M724,320 L748,320 M736,308 L736,332 " stroke="black"/>
# <path d="M800,128 L800,320 " stroke="black"/>
# <circle cx="800" cy="128" r="12" stroke="none" fill="black"/>
# <circle cx="800" cy="320" r="12" stroke="black" fill="white"/>
# <path d="M788,320 L812,320 M800,308 L800,332 " stroke="black"/>
# <rect x="784" y="368" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="800" y="384">H</text>
# <path d="M864,384 L864,448 " stroke="black"/>
# <circle cx="864" cy="384" r="12" stroke="none" fill="black"/>
# <circle cx="864" cy="448" r="12" stroke="black" fill="white"/>
# <path d="M852,448 L876,448 M864,436 L864,460 " stroke="black"/>
# <rect x="848" y="112" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="864" y="128">H</text>
# <path d="M928,128 L928,640 " stroke="black"/>
# <circle cx="928" cy="128" r="12" stroke="none" fill="black"/>
# <circle cx="928" cy="640" r="12" stroke="black" fill="white"/>
# <path d="M916,640 L940,640 M928,628 L928,652 " stroke="black"/>
# <path d="M992,512 L992,576 " stroke="black"/>
# <circle cx="992" cy="576" r="12" stroke="none" fill="black"/>
# <circle cx="992" cy="512" r="12" stroke="black" fill="white"/>
# <path d="M980,512 L1004,512 M992,500 L992,524 " stroke="black"/>
# <path d="M992,128 L992,192 " stroke="black"/>
# <circle cx="992" cy="128" r="12" stroke="none" fill="black"/>
# <circle cx="992" cy="192" r="12" stroke="black" fill="white"/>
# <path d="M980,192 L1004,192 M992,180 L992,204 " stroke="black"/>
# <path d="M1056,64 L1056,128 " stroke="black"/>
# <circle cx="1056" cy="64" r="12" stroke="none" fill="black"/>
# <circle cx="1056" cy="128" r="12" stroke="black" fill="white"/>
# <path d="M1044,128 L1068,128 M1056,116 L1056,140 " stroke="black"/>
# <path d="M1120,64 L1120,384 " stroke="black"/>
# <circle cx="1120" cy="384" r="12" stroke="none" fill="black"/>
# <circle cx="1120" cy="64" r="12" stroke="black" fill="white"/>
# <path d="M1108,64 L1132,64 M1120,52 L1120,76 " stroke="black"/>
# <path d="M1184,64 L1184,192 " stroke="black"/>
# <circle cx="1184" cy="192" r="12" stroke="none" fill="black"/>
# <circle cx="1184" cy="64" r="12" stroke="black" fill="white"/>
# <path d="M1172,64 L1196,64 M1184,52 L1184,76 " stroke="black"/>
# </svg>

# %%
profile = kl_profile(config["N"], config["K"], gates, config["D"])
print(profile)
# Out:
# {1: 0, 2: 0, 3: 42}
